# %%
from auth import get_access_token
from extract import get_activities
import pandas as pd

token = get_access_token()
data = get_activities(token)

df = pd.json_normalize(data)

# %%
df.head()
# Out:
#    resource_state                name  distance  moving_time  elapsed_time  \
# 0               2        Evening Ride   38025.2         5352          5429
# 1               2         Evening Run    6015.4         2148          2148
# 2               2           Lunch Run    5013.7         1649          1649
# 3               2  Last evening in DD    6475.9         4440          4455
# 4               2           Ben Nevis   16322.4        19585         25276
#
#    total_elevation_gain  type sport_type  workout_type            device_name  \
# 0                 373.0  Ride       Ride           NaN  Garmin Forerunner 255
# 1                  64.0   Run        Run           3.0  Garmin Forerunner 255
# 2                  47.0   Run        Run           3.0  Garmin Forerunner 255
# 3                 153.0  Walk       Walk           NaN  Garmin Forerunner 255
# 4                1353.0  Hike       Hike           NaN  Garmin Forerunner 255
#
#    ...  suffer_score athlete.id athlete.id_str athlete.resource_state  \
# 0  ...          23.0   90405244       90405244                      1
# 1  ...          11.0   90405244       90405244                      1
# 2  ...          20.0   90405244       90405244                      1
# 3  ...           8.0   90405244       90405244                      1
# 4  ...          46.0   90405244       90405244                      1
#
#          map.id                               map.summary_polyline  \
# 0  a19181098123  oyc}Hp~vI~AyDn@g@`Bm@p@_GPOfQrG~G?PgOd@aBjAgBJ...
# 1  a19155240969  ijc}HzowIVAFEf@}@FGnCsA|@s@bAg@v@cArC{DtAk@h@Y...
# 2  a19097377224  }jc}H~owIp@OPQVg@TSbCgAXS^]z@e@TUt@kAl@q@v@gAL...
# 3  a19002170755  ib~eI`dcIJXLLVFX\LB\IhAHV?VORa@BAJ|@GfA@LBDl@g...
# 4  a18946237985  apvyIve~]O_SKk@Aq@No@z@cAfEuFdCmGtAaCp@]l@}An@...
#
#   map.resource_state average_cadence max_watts  weighted_average_watts
# 0                  2             NaN       NaN                     NaN
# 1                  2            88.0     501.0                   335.0
# 2                  2            88.0     507.0                   358.0
# 3                  2            56.2       NaN                     NaN
# 4                  2            54.9       NaN                     NaN
#
# [5 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   resource_state                 50 non-null     int64
#  1   name                           50 non-null     object
#  2   distance                       50 non-null     float64
#  3   moving_time                    50 non-null     int64
#  4   elapsed_time                   50 non-null     int64
#  5   total_elevation_gain           50 non-null     float64
#  6   type                           50 non-null     object
#  7   sport_type                     50 non-null     object
#  8   workout_type                   35 non-null     float64
#  9   device_name                    50 non-null     object
#  10  id                             50 non-null     int64
#  11  id_str                         50 non-null     object
#  12  start_date                     50 non-null     object
#  13  start_date_local               50 non-null     object
#  14  timezone                       50 non-null     object
#  15  utc_offset                     50 non-null     float64
#  16  location_city                  0 non-null      object
#  17  location_state                 0 non-null      object
#  18  location_country               0 non-null      object
#  19  achievement_count              50 non-null     int64
#  20  kudos_count                    50 non-null     int64
#  21  comment_count                  50 non-null     int64
#  22  athlete_count                  50 non-null     int64
#  23  photo_count                    50 non-null     int64
#  24  trainer                        50 non-null     bool
#  25  commute                        50 non-null     bool
#  26  manual                         50 non-null     bool
#  27  private                        50 non-null     bool
#  28  visibility                     50 non-null     object
#  29  flagged                        50 non-null     bool
#  30  gear_id                        38 non-null     object
#  31  start_latlng                   50 non-null     object
#  32  end_latlng                     50 non-null     object
#  33  average_speed                  50 non-null     float64
#  34  max_speed                      50 non-null     float64
#  35  average_watts                  39 non-null     float64
#  36  device_watts                   39 non-null     object
#  37  kilojoules                     39 non-null     float64
#  38  has_heartrate                  50 non-null     bool
#  39  average_heartrate              50 non-null     float64
#  40  max_heartrate                  50 non-null     float64
#  41  heartrate_opt_out              50 non-null     bool
#  42  display_hide_heartrate_option  50 non-null     bool
#  43  elev_high                      50 non-null     float64
#  44  elev_low                       50 non-null     float64
#  45  upload_id                      50 non-null     int64
#  46  upload_id_str                  50 non-null     object
#  47  external_id                    50 non-null     object
#  48  from_accepted_tag              50 non-null     bool
#  49  pr_count                       50 non-null     int64
#  50  total_photo_count              50 non-null     int64
#  51  has_kudoed                     50 non-null     bool
#  52  suffer_score                   50 non-null     float64
#  53  athlete.id                     50 non-null     int64
#  54  athlete.id_str                 50 non-null     object
#  55  athlete.resource_state         50 non-null     int64
#  56  map.id                         50 non-null     object
#  57  map.summary_polyline           50 non-null     object
#  58  map.resource_state             50 non-null     int64
#  59  average_cadence                39 non-null     float64
#  60  max_watts                      32 non-null     float64
#  61  weighted_average_watts         32 non-null     float64
# dtypes: bool(10), float64(16), int64(15), object(21)
# memory usage: 20.9+ KB
