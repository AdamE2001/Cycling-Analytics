# %%
import numpy as np
import pandas as pd

df = pd.read_csv("C:/Users/adjel/OneDrive/Desktop/Strava analysis/data/raw/activities.csv")

# %%
df.columns
# Out:
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'sport_type', 'workout_type',
#        'device_name', 'id', 'id_str', 'start_date', 'start_date_local',
#        'timezone', 'utc_offset', 'location_city', 'location_state',
#        'location_country', 'achievement_count', 'kudos_count', 'comment_count',
#        'athlete_count', 'photo_count', 'trainer', 'commute', 'manual',
#        'private', 'visibility', 'flagged', 'gear_id', 'start_latlng',
#        'end_latlng', 'average_speed', 'max_speed', 'average_cadence',
#        'average_watts', 'max_watts', 'weighted_average_watts', 'device_watts',
#        'kilojoules', 'has_heartrate', 'average_heartrate', 'max_heartrate',
#        'heartrate_opt_out', 'display_hide_heartrate_option', 'elev_high',
#        'elev_low', 'upload_id', 'upload_id_str', 'external_id',
#        'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed',
# ...

# %%
df.head()
# Out:
#    resource_state                name  distance  moving_time  elapsed_time  \
# 0               2         Evening Run    5008.0         2011          2085
# 1               2        Evening Ride   38025.2         5352          5429
# 2               2         Evening Run    6015.4         2148          2148
# 3               2           Lunch Run    5013.7         1649          1649
# 4               2  Last evening in DD    6475.9         4440          4455
#
#    total_elevation_gain  type sport_type  workout_type            device_name  \
# 0                  40.0   Run        Run           3.0  Garmin Forerunner 255
# 1                 373.0  Ride       Ride           NaN  Garmin Forerunner 255
# 2                  64.0   Run        Run           3.0  Garmin Forerunner 255
# 3                  47.0   Run        Run           3.0  Garmin Forerunner 255
# 4                 153.0  Walk       Walk           NaN  Garmin Forerunner 255
#
# ...

# %% [markdown]
# Units need to be converted to more usable ones, currently they look to be: distance:metres, time:seconds
# workout_type looks to be a numerical version of the option on strava for workout, race, commute etc.
# There are codes to get location data
# heart rate data, lat and long

# %%
df.shape
# Out:
# (369, 62)

# %% [markdown]
# 369 activities to analyse, 62 columns

# %%
df.tail()
# Out:
#      resource_state           name  distance  moving_time  elapsed_time  \
# 364               2     Lunch Ride  124937.0        22007        441872
# 365               2    Evening Run    4359.2         1832          1846
# 366               2    Evening Run    4896.2         2010          2019
# 367               2    Evening Run    4984.4         2032          2036
# 368               2  Afternoon Run    4621.1         2102          2171
#
#      total_elevation_gain  type sport_type  workout_type device_name  ...  \
# 364                 361.9  Ride       Ride          10.0  Strava App  ...
# 365                  75.3   Run        Run           0.0  Strava App  ...
# 366                  90.3   Run        Run           0.0  Strava App  ...
# 367                  95.4   Run        Run           0.0  Strava App  ...
# 368                  84.1   Run        Run           3.0  Strava App  ...
#
#      pr_count  total_photo_count has_kudoed suffer_score athlete.id  \
# ...
